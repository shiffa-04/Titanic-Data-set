# %%
import pandas as pd

df =pd.read_csv("train.csv")
print(df)
print(df.shape)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#-------number of passengers----------

total_passenger = df.PassengerId.count()
print(f"Total number of passengers : {total_passenger}")
# Out:
# Total number of passengers : 891

# %%
#-------number of passengers who survived----------
import matplotlib.pyplot as plt
survived_passen = df['Survived'].sum()
print(f"Total number of passengers who survived: {survived_passen}")

shades = ['blue','lawngreen']
data={
    'Total Passengers' : total_passenger,
    'Total Survived': survived_passen
}
plt.title("Survival Outcome Among Total Passengers")
plt.pie(data.values(), labels=data.keys(), shadow=True, colors=shades, autopct='%2.1f%%')
plt.legend(loc ='center left', bbox_to_anchor=(1.2,0.7))
plt.show()
# Out:
# Total number of passengers who survived: 342

# %%
#-------number of male passengers----------

male_count = (df['Sex'] == 'male').sum()
print(f"Total number of Male passengers: {male_count}")

#-------number of female passengers---------

female_count = (df['Sex'] == 'female').sum()
print(f"Total number of Female passengers: {female_count}")
# Out:
# Total number of Male passengers: 577
# Total number of Female passengers: 314

# %%
#-------number of male passengers who survived----------

male_survived = ((df['Sex']=='male') & (df['Survived'] == 1)).sum()
print(f"Total number of male passengers who survived: {male_survived}")

#-------number of female passengers who survived----------

female_survived = ((df['Sex'] =='female') & (df['Survived']==1)).sum()
print(f"Total number of female passengers who survived: {female_survived}")
# Out:
# Total number of male passengers who survived: 109
# Total number of female passengers who survived: 233

# %%
import matplotlib.pyplot as plt

data ={
    'Male':male_count,
    'Female':female_count,
    'Female Survived':female_survived,
    'Male Survived':male_survived
    
}
shades = ['#66b3ff','#ff9999','#ffcc99','#99ff99']
plt.title("Survival based on gender")
plt.pie(data.values(), labels=data.keys(),colors=shades, shadow=True,startangle=180,autopct ='%2.1f%%')
plt.legend(loc='center left', bbox_to_anchor =(1,0.5))
plt.show()

# %%
#---- Missing values-------

missing_values = df.isnull().sum() 
print(f"Total number of missing values in each column:\n{missing_values}")
# Out:
# Total number of missing values in each column:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#-----Passengers of different Classes-----

class1_passengers = (df['Pclass'] ==1).sum()
print(f"Total number of passengers of Class 1: {class1_passengers}")
class2_passengers = (df['Pclass'] ==2).sum()
print(f"Total number of passengers of Class 2: {class2_passengers}")
class3_passengers = (df['Pclass'] ==3).sum()
print(f"Total number of passengers of Class 3: {class3_passengers}")
# Out:
# Total number of passengers of Class 1: 216
# Total number of passengers of Class 2: 184
# Total number of passengers of Class 3: 491

# %%
import matplotlib.pyplot as plt
label=['Class 1','Class 2','Class 3']
data =[class1_passengers , class2_passengers, class3_passengers]
shades = ['mediumpurple','#ff9999','lightgray']
plt.title("Distribution based on Classes")
plt.pie(data, labels=label,colors=shades, shadow=True,startangle=180,autopct ='%2.1f%%')
plt.legend(loc='center left', bbox_to_anchor =(1,0.5))
plt.show()

# %%
#------Survival based on Classes-------#

class1_survived = ((df['Pclass'] ==1) & (df['Survived']==1)).sum()
print(f"Total number of passengers of class 1 who survived: {class1_survived}")

class2_survived = ((df['Pclass'] ==2) & (df['Survived']==1)).sum()
print(f"Total number of passengers of class 2 who survived: {class2_survived}")

class3_survived = ((df['Pclass'] ==3) & (df['Survived']==1)).sum()
print(f"Total number of passengers of class 3 who survived: {class3_survived}")
# Out:
# Total number of passengers of class 1 who survived: 136
# Total number of passengers of class 2 who survived: 87
# Total number of passengers of class 3 who survived: 119

# %%
#------Death based on Classes-------#

class1_died = ((df['Pclass'] ==1) & (df['Survived']==0)).sum()
print(f"Total number of passengers of class 1 who died: {class1_died}")

class2_died = ((df['Pclass'] ==2) & (df['Survived']==0)).sum()
print(f"Total number of passengers of class 2 who died: {class2_died}")

class3_died = ((df['Pclass'] ==3) & (df['Survived']==0)).sum()
print(f"Total number of passengers of class 3 who died: {class3_died}")
# Out:
# Total number of passengers of class 1 who died: 80
# Total number of passengers of class 2 who died: 97
# Total number of passengers of class 3 who died: 372

# %%
import matplotlib.pyplot as plt

shades = ['#ff9999','#66b3ff','#99ff99','#ffcc99', 'peru','burlywood']
data={
    'Class 1' : class1_passengers,
    'C1 Survived': class1_survived,
    'Class 2' : class2_passengers,
    'C2 Survived': class2_survived,
    'Class 3' : class3_passengers,
    'C3 Survived': class3_survived
}
plt.title("Survival based on Classes")
plt.pie(data.values(), labels=data.keys(), shadow=True, colors=shades, autopct='%2.1f%%')
plt.legend(loc ='center left', bbox_to_anchor=(1.2,0.7))
plt.show()

# %%
#total male vs male who survived
male_survived = ((df['Sex']=='male') & (df['Survived'] == 1)).sum()
print(male_survived)
male_died = ((df['Sex']=='male') & (df['Survived'] == 0)).sum()
print(male_died)
# Out:
# 109
# 468

# %%
survived_passen = df['Survived'].sum()
print(f"Total number of passengers who survived: {survived_passen}")

shades = ['lawngreen',"red"]
data={
    'Survived' : class1_survived,
    'Died': class1_died
}
plt.title("Analysis of Survival and Death Rates Among Class 1 Passengers")
plt.pie(data.values(), labels=data.keys(), shadow=True, colors=shades, autopct='%2.1f%%')
plt.legend(loc ='center left', bbox_to_anchor=(1.2,0.7))
plt.show()
# Out:
# Total number of passengers who survived: 342

# %%
survived_passen = df['Survived'].sum()
print(f"Total number of passengers who survived: {survived_passen}")

shades = ['lawngreen',"red"]
data={
    'Survived' : class2_survived,
    'Died': class2_died
}
plt.title("Analysis of Survival and Death Rates Among Class 2 Passengers")
plt.pie(data.values(), labels=data.keys(), shadow=True, colors=shades, autopct='%2.1f%%')
plt.legend(loc ='center left', bbox_to_anchor=(1.2,0.7))
plt.show()
# Out:
# Total number of passengers who survived: 342

# %%
survived_passen = df['Survived'].sum()
print(f"Total number of passengers who survived: {survived_passen}")

shades = ['lawngreen',"red"]
data={
    'Survived' : class3_survived,
    'Died': class3_died
}
plt.title("Analysis of Survival and Death Rates Among Class 3 Passengers")
plt.pie(data.values(), labels=data.keys(), shadow=True, colors=shades, autopct='%2.1f%%')
plt.legend(loc ='center left', bbox_to_anchor=(1.2,0.7))
plt.show()
# Out:
# Total number of passengers who survived: 342

# %%
pd.crosstab([df.Sex,df.Survived],df.Pclass,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_8f2be_row0_col0, #T_8f2be_row0_col1, #T_8f2be_row0_col3, #T_8f2be_row3_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_8f2be_row0_col2, #T_8f2be_row1_col2 {
#   background-color: #f1f866;
#   color: #000000;
# }
# #T_8f2be_row1_col0 {
#   background-color: #96cb66;
#   color: #000000;
# }
# #T_8f2be_row1_col1 {
#   background-color: #a3d166;
#   color: #000000;
# }
# #T_8f2be_row1_col3 {
#   background-color: #cfe766;
#   color: #000000;
# }
# #T_8f2be_row2_col0 {
#   background-color: #a7d366;
#   color: #000000;
# }
# #T_8f2be_row2_col1, #T_8f2be_row2_col3 {
#   background-color: #85c266;
#   color: #000000;
# }
# #T_8f2be_row2_col2 {
#   background-color: #6eb666;
#   color: #f1f1f1;
# }
# #T_8f2be_row3_col0 {
#   background-color: #cde666;
#   color: #000000;
# }
# #T_8f2be_row3_col1 {
#   background-color: #f0f866;
#   color: #000000;
# }
# #T_8f2be_row3_col3 {
#   background-color: #f7fb66;
#   color: #000000;
# }
# ...

# %%
import seaborn as sns
sns.catplot(x="Pclass", y="Survived", hue="Sex", data=df)
plt.show()
# Out:
# C:\Users\shiff\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\shiff\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
shades = ['lawngreen','red']
data={
    'Male Survived' : male_survived,
    'Male Died': male_died
}
plt.title("Survival Outcome Among Male Passengers")
plt.pie(data.values(), labels=data.keys(), shadow=True, colors=shades, autopct='%2.1f%%')
plt.legend(loc ='center left', bbox_to_anchor=(1.2,0.7))
plt.show()

# %%
#total female vs female who survived
female_survived = ((df['Sex'] =='female') & (df['Survived']==1)).sum()
print(female_survived)
female_died = ((df['Sex'] =='female') & (df['Survived']==0)).sum()
print(female_died)
# Out:
# 233
# 81

# %%
shades = ['lawngreen','red']
data={
    'Female Survived' : female_survived,
    'Female Died': female_died
}
plt.title("Survival Outcome Among Female Passengers")
plt.pie(data.values(), labels=data.keys(), shadow=True, colors=shades, autopct='%2.1f%%')
plt.legend(loc ='center left', bbox_to_anchor=(1.2,0.7))
plt.show()

# %%
#filling missing Age value for males based on class

meanAgeMale = df[df['Sex']=="male"].groupby('Pclass')["Age"].mean()

for pclass , meanAge in meanAgeMale.items():
    df.loc[(df['Sex']=="male") & (df['Pclass']==pclass) & df['Age'].isnull(), 'Age']=meanAge

#filling missing age values for female based on title

MeanMissTitle = df[df['Name'].str.contains('Miss') & (df['Sex']=='female')]['Age'].mean()
df.loc[df['Name'].str.contains('Miss') & (df['Sex']=='female') &(df['Age'].isnull()), 'Age'] = MeanMissTitle

MeanMrsTitle = df[df['Name'].str.contains('Mrs') & (df['Sex']=="female")]['Age'].mean()
df.loc[(df['Sex']=="female") & (df['Name'].str.contains('Mrs')) & df['Age'].isnull(), 'Age'] = MeanMrsTitle

print(df['Age'].isnull().sum())
# Out:
# 0

# %%
#------------Distribution of Age Group------------------

infants = ((df['Age']  > 0) & (df["Age"] <= 4)).sum()
children = ((df['Age'] >= 5) & (df["Age"] <=12)).sum()
Teenagers = ((df['Age'] >=13) & (df["Age"] <= 19)).sum()
YoungAdults = ((df['Age'] >=20) & (df["Age"]<= 29)).sum()
Adults = ((df['Age'] >=30) & (df["Age"] <= 59)).sum()
Seniors = (df['Age'] >=60).sum()
print(infants,children,Teenagers,YoungAdults,Adults,Seniors)
# Out:
# 40 29 95 350 351 26

# %%
#------------Survival based on Age Group--------------

sur_infants = (((df['Age']  > 0) & (df["Age"] <= 4)) & df['Survived']==1).sum()
sur_children =(((df['Age'] >= 5) & (df["Age"] <=12)) & df['Survived']==1).sum()
sur_Teenagers = (((df['Age'] >=13) & (df["Age"] <= 19)) & df['Survived']==1).sum()
sur_YoungAdults = (((df['Age'] >=20) & (df["Age"]<= 29)) & df['Survived']==1).sum()
sur_Adults = (((df['Age'] >=30) & (df["Age"] <= 59)) & df['Survived']==1).sum()
sur_Seniors = ((df['Age'] >=60) & df['Survived']==1).sum()
print(sur_infants, sur_children, sur_Teenagers, sur_YoungAdults, sur_Adults, sur_Seniors)
# Out:
# 27 13 39 108 148 7

# %%
import numpy as np

age_group = ['infants', 'children', 'Teenagers', 'Young Adults', 'Adults', 'Seniors']

#count--------
count =[infants, children, Teenagers, YoungAdults, Adults, Seniors]
survived_count = [sur_infants, sur_children, sur_Teenagers, sur_YoungAdults, sur_Adults, sur_Seniors]

bar_width=0.20

index = np.arange(len(count))

plt.figure(figsize=(10, 6))
plt.bar(index,count, bar_width, color='blue', label = "Total Count")
plt.bar(index + 0.20, survived_count,  bar_width,color='lawngreen', label = "Survival Count")


plt.title('Total Count of Passengers by Age Group and Survival Status')
plt.xlabel("Age Group")
plt.ylabel("Total Count")
plt.xticks(index + 0.10,('infants\n(Ages 0-4)','children\n(Ages 5-12)', 'Teenagers\n(Ages 13-19)', 'Young Adults\n(Ages 20-29)', 'Adults\n(Ages 30-59)','Seniors\n(Ages 60 and above)'))
plt.legend()
plt.show()
f,ax=plt.subplots(1,2,figsize=(20,10))
df[df['Survived']==0].Age.plot.hist(ax=ax[0],bins=20,edgecolor='black',color='red')
ax[0].set_title('Survived= 0')
x1=list(range(0,85,5))
ax[0].set_xticks(x1)
df[df['Survived']==1].Age.plot.hist(ax=ax[1],color='green',bins=20,edgecolor='black')
ax[1].set_title('Survived= 1')
x2=list(range(0,85,5))
ax[1].set_xticks(x2)
plt.show()

# %%
#-------Distribution of Total passengers based on their boarding location ------

location = df['Embarked'].value_counts()
print(location)
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
shades = ['lawngreen','red','blue']
boardingLocations =['Southampton (S)','Cherbourg (C)','Queenstown (Q)']
data = location
plt.title("Distribution of Total passengers based on their boarding location")
plt.pie(data, labels=boardingLocations, shadow=True, colors=shades, autopct='%2.1f%%')
plt.legend(loc ='center left', bbox_to_anchor=(1.2,0.7))
plt.show()

# %%
#-------Distribution of Survived passengers based on their boarding location---

survived_passengers_df = df[df['Survived']==1]

grEm = survived_passengers_df.groupby('Embarked')['PassengerId'].count()

survivors_s =grEm.get("S")
survivors_c =grEm.get("C")
survivors_q =grEm.get("Q")

print("Survivors from Southampton (S):", survivors_s)
print("Survivors from Cherbourg (C):", survivors_c)
print("Survivors from Queenstown (Q):", survivors_q)
# Out:
# Survivors from Southampton (S): 217
# Survivors from Cherbourg (C): 93
# Survivors from Queenstown (Q): 30

# %%
#-------Distribution of Died passengers based on their boarding location---

died_passengers_df = df[df['Survived']==0]

grEm = died_passengers_df.groupby('Embarked')['PassengerId'].count()

died_s =grEm.get("S")
died_c =grEm.get("C")
died_q =grEm.get("Q")

print("Number of Died passengers from Southampton (S):", died_s)
print("Number of Died passengers from Cherbourg (C):", died_c)
print("Number of Died passengers from Queenstown (Q):", died_q)
# Out:
# Number of Died passengers from Southampton (S): 427
# Number of Died passengers from Cherbourg (C): 75
# Number of Died passengers from Queenstown (Q): 47

# %%
boardingLocations =[ 'Southampton (S)','Cherbourg (C)','Queenstown (Q)' ]
count =location
survived_count = [survivors_s, survivors_c, survivors_q]

index = np.arange(len(boardingLocations))

bar_width =0.20

plt.figure(figsize=(6,6))

plt.bar(index, count, bar_width, color='blue', label="Total Passengers")
plt.bar(index,survived_count, bar_width, color='lawngreen',label="Survived Passengers")

plt.title("Survival and Death Rate Among Passengers Boarding from Different Ports")
plt.xlabel("Embarkation Port")
plt.ylabel("Number of Passengers")
plt.xticks(index + 0.10,(boardingLocations))
plt.legend()
plt.tight_layout()
plt.show()

# %%
shades = ['lawngreen','red']
data={
    'Survived' : survivors_s,
    'Died': died_s
}
plt.title("Survival and Death Rate Among Passengers Boarding from Southampton (S) Port")
plt.pie(data.values(), labels=data.keys(), shadow=True, colors=shades, autopct='%2.1f%%')
plt.legend(loc ='center left', bbox_to_anchor=(1.2,0.7))
plt.show()

# %%
shades = ['lawngreen','red']
data={
    'Survived' : survivors_c,
    'Died': died_c
}
plt.title("Survival and Death Rate Among Passengers Boarding from Cherbourg (C) Port")
plt.pie(data.values(), labels=data.keys(), shadow=True, colors=shades, autopct='%2.1f%%')
plt.legend(loc ='center left', bbox_to_anchor=(1.2,0.7))
plt.show()

# %%
shades = ['lawngreen','red']
data={
    'Survived' : survivors_q,
    'Died': died_q
}
plt.title("Survival and Death Rate Among Passengers Boarding from Queenstown (Q) Port")
plt.pie(data.values(), labels=data.keys(), shadow=True, colors=shades, autopct='%2.1f%%')
plt.legend(loc ='center left', bbox_to_anchor=(1.2,0.7))
plt.show()

# %%
df['FamilySize'] = df['SibSp'] + df['Parch']
print(df['FamilySize'].max())
survival_rate_by_family_size = df.groupby('FamilySize')['Survived'].mean()
print(f"Survival Rate by Family Size:{survival_rate_by_family_size}")
# Out:
# 10
# Survival Rate by Family Size:FamilySize
# 0     0.303538
# 1     0.552795
# 2     0.578431
# 3     0.724138
# 4     0.200000
# 5     0.136364
# 6     0.333333
# 7     0.000000
# 10    0.000000
# Name: Survived, dtype: float64

# %%
shades = ['#ff9999','#66b3ff','#99ff99','#ffcc99', 'peru','burlywood','lightsteelblue']
data ={
        0:  0.303538,
        1:  0.552795,
        2:  0.578431,
        3:  0.724138,
        4:  0.200000,
        5:  0.136364,
        6:  0.333333,
}

plt.figure(figsize=(8,10))
plt.pie(data.values(), labels=data.keys(), colors=shades, shadow=True, autopct="%2.1f%%",textprops={'fontsize': 8})
plt.title('Correlation Between Family Size and Survival Rate')
plt.legend(title="Family Size",loc='center left',bbox_to_anchor=(1, 0.5),fontsize=10)
plt.show()

# %%
#correlation matrix
# Dropping non-numeric columns 
df['Sex']=df['Sex'].replace({'male':1, 'female':0})
numeric_df = df.select_dtypes(include=['number'])
correlation_matrix = numeric_df.corr()
print(correlation_matrix)
# Out:
#              PassengerId  Survived    Pclass       Sex       Age     SibSp  \
# PassengerId     1.000000 -0.005007 -0.035144  0.042939  0.036847 -0.057527
# Survived       -0.005007  1.000000 -0.338481 -0.543351 -0.077221 -0.035322
# Pclass         -0.035144 -0.338481  1.000000  0.131900 -0.369226  0.083081
# Sex             0.042939 -0.543351  0.131900  1.000000  0.093254 -0.114631
# Age             0.036847 -0.077221 -0.369226  0.093254  1.000000 -0.308247
# SibSp          -0.057527 -0.035322  0.083081 -0.114631 -0.308247  1.000000
# Parch          -0.001652  0.081629  0.018443 -0.245489 -0.189119  0.414838
# Fare            0.012658  0.257307 -0.549500 -0.182333  0.096067  0.159651
#
#                 Parch      Fare
# PassengerId -0.001652  0.012658
# Survived     0.081629  0.257307
# Pclass       0.018443 -0.549500
# Sex         -0.245489 -0.182333
# Age         -0.189119  0.096067
# SibSp        0.414838  0.159651
# Parch        1.000000  0.216225
# ...

# %%
sns.heatmap(correlation_matrix,annot=True,cmap='RdYlGn',linewidths=0.2)
fig=plt.gcf()
fig.set_size_inches(10,8)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
shades=['rebeccapurple','violet','lightgrey']
df['Pclass'] = df['Pclass'].astype(str)
hue_order=['1','2','3']
plt.figure(figsize=(8, 6))
plt.title('Embarked vs Pclass')
sns.countplot(x='Embarked',hue='Pclass',data=df,palette = shades, hue_order = hue_order)
plt.legend(title='Passenger Class',bbox_to_anchor=(0.75, 1), loc='upper left')
plt.show()

# %%
pd.crosstab(df['SibSp'],df['Survived'], margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_79238_row0_col0 {
#   background-color: #47a366;
#   color: #f1f1f1;
# }
# #T_79238_row0_col1 {
#   background-color: #62b066;
#   color: #f1f1f1;
# }
# #T_79238_row0_col2 {
#   background-color: #51a866;
#   color: #f1f1f1;
# }
# #T_79238_row1_col0 {
#   background-color: #d4ea66;
#   color: #000000;
# }
# #T_79238_row1_col1 {
#   background-color: #acd666;
#   color: #000000;
# }
# #T_79238_row1_col2 {
#   background-color: #c5e266;
#   color: #000000;
# }
# #T_79238_row2_col0, #T_79238_row4_col0 {
#   background-color: #fbfd66;
#   color: #000000;
# }
# #T_79238_row2_col1 {
#   background-color: #f6fa66;
#   color: #000000;
# }
# #T_79238_row2_col2 {
#   background-color: #f9fc66;
#   color: #000000;
# }
# #T_79238_row3_col0, #T_79238_row3_col2, #T_79238_row4_col2 {
#   background-color: #fcfe66;
#   color: #000000;
# }
# #T_79238_row3_col1, #T_79238_row4_col1 {
#   background-color: #fdfe66;
#   color: #000000;
# }
# ...
